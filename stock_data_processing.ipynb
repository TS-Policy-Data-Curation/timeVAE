# %%
import numpy as np

loaded = np.load("./outputs/gen_data/macroeconomic/timeVAE_macroeconomic_prior_samples.npz")
synth_data = loaded["data"]
print(synth_data.shape) # Output: (764, 24, 6)
print(synth_data[0][0])

og_data = np.load("/home/vincentwork/timeVAE/data/macroeconomic.npz")
og_data = loaded["data"]
print(og_data.shape) # Output: (764, 24, 6)
print(og_data[0][0])
### NOTES ###
    # Samples, Timestamps, Features
    # Percent 20 means 20% of the full data
    # 100% data for stocks is 3919
### Investigate Further ###
    # Why are there multiple samples (is this for mean and standard deviation)
    # What are the features
    # What are the timestamps
# Out:
# (900, 64, 3)
# [5.1986165e+00 1.4551734e+00 3.5171816e+03]
# (900, 64, 3)
# [5.1986165e+00 1.4551734e+00 3.5171816e+03]

# %%
stock_loaded = np.load("/home/vincentwork/timeVAE/data/stockv_subsampled_train_perc_5.npz")
stockv = stock_loaded["data"]
print(stockv.shape) # Output: (764, 24, 6)
print(stockv)
# Out:
# (173, 24, 6)
# [[[2.90371876e+01 2.90371876e+01 2.82577686e+01 2.82730503e+01
#    2.82730503e+01 5.76729000e+05]
#   [2.81762619e+01 2.88079472e+01 2.80794697e+01 2.87519093e+01
#    2.87519093e+01 2.78942000e+05]
#   [2.85583286e+01 2.90524712e+01 2.84105968e+01 2.88741722e+01
#    2.88741722e+01 4.76420000e+05]
#   ...
#   [3.10443192e+01 3.23076935e+01 3.07692318e+01 3.22822227e+01
#    3.22822227e+01 2.29612100e+06]
#   [3.20275078e+01 3.20427933e+01 3.14060116e+01 3.15690269e+01
#    3.15690269e+01 1.02350800e+06]
#   [3.16607227e+01 3.26337242e+01 3.16607227e+01 3.25878754e+01
#    3.25878754e+01 8.92772000e+05]]
#
#  [[2.81762619e+01 2.88079472e+01 2.80794697e+01 2.87519093e+01
#    2.87519093e+01 2.78942000e+05]
#   [2.85583286e+01 2.90524712e+01 2.84105968e+01 2.88741722e+01
#    2.88741722e+01 4.76420000e+05]
#   [2.89709625e+01 2.90626583e+01 2.85736122e+01 2.88690777e+01
#    2.88690777e+01 5.82422000e+05]
#   ...
# ...
